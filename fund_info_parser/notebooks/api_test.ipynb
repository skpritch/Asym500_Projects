# %%
# Cell 1: Imports and helper definitions
#Imports
import sys
sys.path.append('../scripts/')

from pathlib import Path
import json
import pandas as pd
from parse_utils import pdf_to_pages, html_to_text
from llm_client import extract_block

# %%
# Cell 2: Function to parse a directory of 497K PDFs

def parse_497k_directory(directory: str, model: str = 'o4-mini') -> pd.DataFrame:
    """
    Parse all .pdf AND .htm/.html files in `directory`, 
    dispatching based on extension, and return a DataFrame.
    """
    results = []
    data_dir = Path(directory)

    for path in sorted(data_dir.iterdir()):
        suffix = path.suffix.lower()
        if suffix == '.pdf':
            # PDF path → pages → text
            pages = pdf_to_pages(path)
            text = "\n".join(pages)
        elif suffix in ('.htm', '.html'):
            # HTML path → BeautifulSoup → text
            text = html_to_text(path)
        else:
            # skip anything else
            continue

        # send to your LLM extractor
        record = extract_block(text, model=model)
        record['source_file'] = path.name
        results.append(record)

    return pd.DataFrame(results)

# %%
# Cell 3: Run parsing and display results

df = parse_497k_directory('../data/raw/a5filings_test', model='o4-mini')
df.head()
# Out:
#                                          fund_name ticker underlying_type  \
# 0                           ProShares Ultra S&P500    SSO           index
# 1                  ProShares UltraPro Short S&P500   SPXU           index
# 2  Direxion Daily S&P 500 High Beta Bull 3X Shares   HIBL           index
# 3  Direxion Daily Travel & Vacation Bull 2X Shares   OOTO           index
# 4               KraneShares 2x Long BABA Daily ETF   KBAB    single_stock
#
#                      underlying_asset fund_basis leveraged_etf  \
# 0                                 SPX      swaps          True
# 1                                 SPX      swaps          True
# 2             S&P 500 High Beta Index      swaps          True
# 3  BlueStar Travel and Vacation Index      swaps          True
# 4                                BABA      swaps          True
#
#    leverage_multiple rebalancing_timescale inception_date  management_fee  \
# 0                2.0                 daily           None            0.75
# 1               -3.0                 daily           None            0.75
# 2                3.0                 daily     11/07/2019            0.75
# 3                2.0                 daily     06/10/2021            0.75
# 4                2.0                 daily     03/12/2025            1.25
#
#    expense_fee  total_operating_fee  net_total_after_waiver  \
# 0         0.14                 0.89                    0.89
# 1         0.14                 0.89                    0.89
# 2         0.23                 0.98                     NaN
# 3         0.37                 1.12                    0.98
# 4         0.01                 1.26                    0.99
#
#                                 investment_objective  \
# 0  ProShares Ultra S&P500 (the "Fund") seeks dail...
# 1  The Fund seeks daily investment results, befor...
# 2  The Fund seeks daily investment results, befor...
# 3  The Fund seeks daily investment results, befor...
# 4  The Fund seeks daily investment results, befor...
#
#                                 principal_strategies  \
# 0  The Fund invests in financial instruments that...
# 1  The Fund invests principally in swap agreement...
# 2  The Fund invests at least 80% of its net asset...
# 3  The Fund invests at least 80% of its net asset...
# 4  Under normal circumstances, the Fund invests a...
#
#                                          source_file
# 0          1174610_0001683863-25-003318_f41376d1.htm
# 1          1174610_0001683863-25-003320_f41378d1.htm
# 2      1424958_0001193125-25-039969_d882427d497k.htm
# 3      1424958_0001193125-25-039976_d889800d497k.htm
# 4  1547576_0001829126-25-001710_kraneshares_497k.htm

# %%
# Cell 4: Save to JSONL for downstream use
out_path = '../data/extracted/'
out_file = 'a5filings_test.jsonl'
output_path = Path(out_path) / out_file

output_path.parent.mkdir(exist_ok=True, parents=True)
with output_path.open('w', encoding='utf-8') as f:
    for rec in df.to_dict(orient='records'):
        f.write(json.dumps(rec, ensure_ascii=False) + '\n')

print(f"Saved parsed data to {output_path}")
# Out:
# Saved parsed data to ../data/extracted/a5filings_test.jsonl
