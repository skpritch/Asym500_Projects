# %%
# Cell 1: Imports and helper definitions
#Imports
import sys
sys.path.append('../scripts/')

from pathlib import Path
import json
import pandas as pd
from pdf_utils import pdf_to_pages
from llm_client import extract_block

# %%
# Cell 2: Function to parse a directory of 497K PDFs

def parse_497k_directory(directory: str, model: str = 'o4-mini') -> pd.DataFrame:
    """
    Parse all 497K PDFs in the given directory and return a DataFrame of extracted metadata.
    """
    results = []
    pdf_dir = Path(directory)
    for pdf_path in sorted(pdf_dir.glob('*.pdf')):
        pages = pdf_to_pages(pdf_path)
        text = "\n".join(pages)
        data = extract_block(text, model=model)
        data.update({'source_file': pdf_path.name})
        results.append(data)
    return pd.DataFrame(results)

# %%
# Cell 3: Run parsing and display results

df = parse_497k_directory('../data/raw/test', model='o4-mini')
df.head()
# Out:
#                                           fund_name ticker underlying_theme  \
# 0                Direxion Daily AAPL Bull 2X Shares   AAPU     single-stock
# 1  iShares Inflation Hedged U.S. Aggregate Bond ETF   AGIH             bond
# 2             GraniteShares 2x Short COIN Daily ETF   CONI     single-stock
# 3                         iShares Gold Strategy ETF   IAUF        commodity
# 4            Defiance Daily Target 2X Long MSTR ETF   MSTX     single-stock
#
#   primary_basis                               benchmark_underlying  \
# 0         swaps                                   AAPL (Apple Inc)
# 1         swaps  BlackRock Inflation Hedged U.S. Aggregate Bond...
# 2         swaps       Coinbase Global, Inc. Class A (NASDAQ: COIN)
# 3         swaps                     Bloomberg Composite Gold Index
# 4         swaps          MicroStrategy Incorporated (Nasdaq: MSTR)
#
#   leverage_percent rebalancing_timescale inception_date management_fee  \
# 0             200%                 daily     08/09/2022          0.75%
# 1             None                 daily     2022-06-23          0.13%
# 2            -200%                 Daily           None          0.99%
# 3             None                  None           None          0.25%
# 4             200%                 daily           None          1.29%
#
#   expense_fee total_operating_fee net_total_after_waiver  \
# 0       0.14%               0.97%                   None
# 1       0.03%               0.16%                  0.13%
# 2       0.44%               1.43%                  1.15%
# 3       0.06%               0.31%                  0.25%
# 4       0.00%               1.29%                  1.29%
#
#   distribution_frequency                  tax_status  \
# 0                   None                        None
# 1                   None                     taxable
# 2                   None  Taxable as ordinary income
# 3                   None                        None
# 4                   None                        None
#
#                                 investment_objective  \
# 0  The Fund seeks daily investment results, befor...
# 1  The Fund seeks to track the investment results...
# 2  The Fund seeks daily investment results, befor...
# 3  The Fund seeks to provide exposure, on a total...
# 4  The Fund seeks daily investment results, befor...
#
#                                 principal_strategies    source_file
# 0  Under normal circumstances, invests at least 8...  aapu_497k.pdf
# 1  Under normal circumstances the Fund invests at...  agih_497k.pdf
# 2  The Fund attempts to replicate -200% of the da...  coni_497k.pdf
# 3  The Fund invests primarily in (i) exchange-tra...  iauf_497k.pdf
# 4  The Fund is an actively managed ETF that seeks...  mstx_497k.pdf

# %%
# Cell 4: Save to JSONL for downstream use

out_path = '../data/extracted/'
out_file = 'parsed_497k_results.jsonl'
output_path = Path(out_path + out_file)
with output_path.open('w', encoding='utf-8') as f:
    for rec in df.to_dict(orient='records'):
        f.write(json.dumps(rec, ensure_ascii=False) + '\n')

print(f"Saved parsed data to {output_path}")
# Out:
# Saved parsed data to ../data/extracted/parsed_497k_results.jsonl
